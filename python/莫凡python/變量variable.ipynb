# %%
apple=10
print(apple)
# Out:
# 10

# %%
apple_egg=10
APPLE_EGG=11
apple_EGG=12+3
print(apple_EGG)
# Out:
# 15

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=1
b=a*2
print(a,b)
# Out:
# 1 2

# %%
condition=1
while condition<10:
    print(condition)
    condition=condition+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
while True:
    print("I'm True")
# Out:
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# I'm True
# ...
